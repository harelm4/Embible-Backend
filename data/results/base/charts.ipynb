# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fine_tuned=pd.read_csv('fine_tuned.csv')
no_fine_tuned=pd.read_csv('no_fine_tuned.csv')
fine_tuned
# Out:
#     Unnamed: 0  k                              model     hit@k  \
# 0            0  1  Embible/AlephBertGimmel-20-epochs  0.161818
# 1            1  1            Embible/mBert-20-epochs  0.047879
# 2            2  1       Embible/distilBert-20-epochs  0.056364
# 3            3  1          Embible/tavbert-20-epochs  0.358182
# 4            4  1  Embible/AlephBertGimmel-20-epochs  0.101845
# 5            5  1            Embible/mBert-20-epochs  0.032292
# 6            6  1       Embible/distilBert-20-epochs  0.036196
# 7            7  1          Embible/tavbert-20-epochs  0.256920
# 8            8  1  Embible/AlephBertGimmel-20-epochs  0.061107
# 9            9  1            Embible/mBert-20-epochs  0.015414
# 10          10  1       Embible/distilBert-20-epochs  0.018717
# 11          11  1          Embible/tavbert-20-epochs  0.208643
#
#                                                  file      time
# 0   ../../data/Hit@K/masked MIX char tokens/mix_5....  1.148221
# 1   ../../data/Hit@K/masked MIX char tokens/mix_5....  1.216987
# 2   ../../data/Hit@K/masked MIX char tokens/mix_5....  1.012340
# 3   ../../data/Hit@K/masked MIX char tokens/mix_5....  1.621325
# 4   ../../data/Hit@K/masked MIX char tokens/mix_10...  1.404636
# 5   ../../data/Hit@K/masked MIX char tokens/mix_10...  1.303313
# 6   ../../data/Hit@K/masked MIX char tokens/mix_10...  1.089011
# 7   ../../data/Hit@K/masked MIX char tokens/mix_10...  1.624494
# 8   ../../data/Hit@K/masked MIX char tokens/mix_15...  1.512111
# 9   ../../data/Hit@K/masked MIX char tokens/mix_15...  1.471898
# 10  ../../data/Hit@K/masked MIX char tokens/mix_15...  1.170832
# 11  ../../data/Hit@K/masked MIX char tokens/mix_15...  2.011055

# %%
no_fine_tuned['model']=no_fine_tuned['model'].replace('tau/tavbert-he','tavBert')
no_fine_tuned['model']=no_fine_tuned['model'].replace('distilbert-base-uncased','distilbert')
no_fine_tuned['model']=no_fine_tuned['model'].replace('bert-base-multilingual-cased','mBert')
no_fine_tuned['model']=no_fine_tuned['model'].replace('dicta-il/alephbertgimmel-base','aleph-bert-gimmel')
no_fine_tuned
# Out:
#     Unnamed: 0  k              model     hit@k  \
# 0            0  1            tavBert  0.329697
# 1            1  1         distilbert  0.000000
# 2            2  1  aleph-bert-gimmel  0.102424
# 3            3  1              mBert  0.016970
# 4            4  1            tavBert  0.228531
# 5            5  1         distilbert  0.000000
# 6            6  1  aleph-bert-gimmel  0.047197
# 7            7  1              mBert  0.009936
# 8            8  1            tavBert  0.171208
# 9            9  1         distilbert  0.000000
# 10          10  1  aleph-bert-gimmel  0.012386
# 11          11  1              mBert  0.004404
#
#                                                  file      time
# 0   ../../data/Hit@K/masked MIX char tokens/mix_5....  1.515398
# 1   ../../data/Hit@K/masked MIX char tokens/mix_5....  0.735068
# 2   ../../data/Hit@K/masked MIX char tokens/mix_5....  1.146932
# 3   ../../data/Hit@K/masked MIX char tokens/mix_5....  1.327944
# 4   ../../data/Hit@K/masked MIX char tokens/mix_10...  1.594671
# 5   ../../data/Hit@K/masked MIX char tokens/mix_10...  0.729863
# 6   ../../data/Hit@K/masked MIX char tokens/mix_10...  1.230189
# 7   ../../data/Hit@K/masked MIX char tokens/mix_10...  1.334014
# 8   ../../data/Hit@K/masked MIX char tokens/mix_15...  1.689159
# 9   ../../data/Hit@K/masked MIX char tokens/mix_15...  0.677596
# 10  ../../data/Hit@K/masked MIX char tokens/mix_15...  1.295241
# 11  ../../data/Hit@K/masked MIX char tokens/mix_15...  1.330682

# %%
fine_tuned['model']=fine_tuned['model'].replace('Embible/tavbert-20-epochs','tavBert')
fine_tuned['model']=fine_tuned['model'].replace('Embible/distilBert-20-epochs','distilbert')
fine_tuned['model']=fine_tuned['model'].replace('Embible/mBert-20-epochs','mBert')
fine_tuned['model']=fine_tuned['model'].replace('Embible/AlephBertGimmel-20-epochs','aleph-bert-gimmel')
fine_tuned
# Out:
#     Unnamed: 0  k              model     hit@k  \
# 0            0  1  aleph-bert-gimmel  0.161818
# 1            1  1              mBert  0.047879
# 2            2  1         distilbert  0.056364
# 3            3  1            tavBert  0.358182
# 4            4  1  aleph-bert-gimmel  0.101845
# 5            5  1              mBert  0.032292
# 6            6  1         distilbert  0.036196
# 7            7  1            tavBert  0.256920
# 8            8  1  aleph-bert-gimmel  0.061107
# 9            9  1              mBert  0.015414
# 10          10  1         distilbert  0.018717
# 11          11  1            tavBert  0.208643
#
#                                                  file      time
# 0   ../../data/Hit@K/masked MIX char tokens/mix_5....  1.148221
# 1   ../../data/Hit@K/masked MIX char tokens/mix_5....  1.216987
# 2   ../../data/Hit@K/masked MIX char tokens/mix_5....  1.012340
# 3   ../../data/Hit@K/masked MIX char tokens/mix_5....  1.621325
# 4   ../../data/Hit@K/masked MIX char tokens/mix_10...  1.404636
# 5   ../../data/Hit@K/masked MIX char tokens/mix_10...  1.303313
# 6   ../../data/Hit@K/masked MIX char tokens/mix_10...  1.089011
# 7   ../../data/Hit@K/masked MIX char tokens/mix_10...  1.624494
# 8   ../../data/Hit@K/masked MIX char tokens/mix_15...  1.512111
# 9   ../../data/Hit@K/masked MIX char tokens/mix_15...  1.471898
# 10  ../../data/Hit@K/masked MIX char tokens/mix_15...  1.170832
# 11  ../../data/Hit@K/masked MIX char tokens/mix_15...  2.011055

# %%
def replace_file(df):
    for mask_precent in [5,10,15]:
        df['file']=df['file'].replace(f'../../data/Hit@K/masked MIX char tokens/mix_{mask_precent}.json',mask_precent)

replace_file(fine_tuned)
replace_file(no_fine_tuned)

# %%
fine_tuned
# Out:
#     Unnamed: 0  k              model     hit@k  file      time
# 0            0  1  aleph-bert-gimmel  0.161818     5  1.148221
# 1            1  1              mBert  0.047879     5  1.216987
# 2            2  1         distilbert  0.056364     5  1.012340
# 3            3  1            tavBert  0.358182     5  1.621325
# 4            4  1  aleph-bert-gimmel  0.101845    10  1.404636
# 5            5  1              mBert  0.032292    10  1.303313
# 6            6  1         distilbert  0.036196    10  1.089011
# 7            7  1            tavBert  0.256920    10  1.624494
# 8            8  1  aleph-bert-gimmel  0.061107    15  1.512111
# 9            9  1              mBert  0.015414    15  1.471898
# 10          10  1         distilbert  0.018717    15  1.170832
# 11          11  1            tavBert  0.208643    15  2.011055

# %%
def plot(df,title):
    df = df.sort_values('hit@k', ascending=False)
    sns.barplot(x='model',y='hit@k',hue='file',data=df)
    plt.legend().set_title(None)
    plt.ylabel('Precision (Hit@1)')

    plt.title(title)
    plt.show()

plot(fine_tuned,'Fine Tuned Models')
plot(no_fine_tuned,'As Is Models')
